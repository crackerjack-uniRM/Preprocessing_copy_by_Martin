# %% [markdown]
# ## 2010_Preprocessing

# %%
# import modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
# read 2010_data

data_2010_1 = pd.read_excel('../data/raw/2010/2010_data1.xlsx')

data_2020_2 = pd.read_csv('../data/raw/2010/2010_data2.csv')

# %%
display(data_2010_1.tail(5), data_2010_1.shape)
# Out:
#        Stkcd     EndDate Same
# 2126  900950  2010-12-31    N
# 2127  900951  2010-12-31    N
# 2128  900953  2010-12-31    N
# 2129  900956  2010-12-31    N
# 2130  900957  2010-12-31    N
# (2131, 3)

# %%
display(data_2010_2.tail(5), data_2010_2.shape)
# Out:
#           证券代码↑  证券简称 所属申万行业名称\n[行业级别] 一级行业  董事会人数\n[交易日期] 2010-12-31  \
# 4769  871857.BJ  泓禧科技                   NaN                       0.0
# 4770  871981.BJ  晶赛科技                   NaN                       0.0
# 4771  872925.BJ  锦好医疗                   NaN                       0.0
# 4772        NaN   NaN                   NaN                       NaN
# 4773  数据来源：Wind   NaN                   NaN                       NaN
#
#       独立董事人数\n[交易日期] 2010-12-31  非独立董事人数\n[交易日期] 2010-12-31  \
# 4769                        0.0                         0.0
# 4770                        0.0                         0.0
# 4771                        0.0                         0.0
# 4772                        NaN                         NaN
# 4773                        NaN                         NaN
#
#      公司监事(历任)\n[交易日期] 2010-12-31  高管人数\n[交易日期] 2010-12-31  \
# 4769                         NaN                      0.0
# 4770                         NaN                      0.0
# ...

# %%
data_2010_2['证券代码↑'] = data_2010_2['证券代码↑'].str.replace(r'[\.A-Za-z]', '', regex=True)

# %%
display(data_2010_2.tail(5), data_2010_2.shape)
# Out:
#        证券代码↑  证券简称 所属申万行业名称\n[行业级别] 一级行业  董事会人数\n[交易日期] 2010-12-31  \
# 4769  871857  泓禧科技                   NaN                       0.0
# 4770  871981  晶赛科技                   NaN                       0.0
# 4771  872925  锦好医疗                   NaN                       0.0
# 4772     NaN   NaN                   NaN                       NaN
# 4773   数据来源：   NaN                   NaN                       NaN
#
#       独立董事人数\n[交易日期] 2010-12-31  非独立董事人数\n[交易日期] 2010-12-31  \
# 4769                        0.0                         0.0
# 4770                        0.0                         0.0
# 4771                        0.0                         0.0
# 4772                        NaN                         NaN
# 4773                        NaN                         NaN
#
#      公司监事(历任)\n[交易日期] 2010-12-31  高管人数\n[交易日期] 2010-12-31  \
# 4769                         NaN                      0.0
# 4770                         NaN                      0.0
# ...

# %%
data_2010 = pd.merge(left=data_2010_1, right=data_2010_2, left_on='Stkcd', right_on='证券代码↑', how='inner')

# %%
display(data_2010.tail(5), data_2010.shape)
# Out:
#        Stkcd     EndDate Same   证券代码↑  证券简称 所属申万行业名称\n[行业级别] 一级行业  \
# 2030  601989  2010-12-31    N  601989  中国重工                  国防军工
# 2031  601991  2010-12-31    N  601991  大唐发电                  公用事业
# 2032  601992  2010-12-31    N  601992  金隅集团                  建筑材料
# 2033  601998  2010-12-31    N  601998  中信银行                    银行
# 2034  601999  2010-12-31    N  601999  出版传媒                    传媒
#
#       董事会人数\n[交易日期] 2010-12-31  独立董事人数\n[交易日期] 2010-12-31  \
# 2030                      13.0                        5.0
# 2031                      15.0                        5.0
# 2032                      11.0                        5.0
# 2033                      16.0                        5.0
# 2034                      12.0                        4.0
#
#       非独立董事人数\n[交易日期] 2010-12-31     公司监事(历任)\n[交易日期] 2010-12-31  \
# 2030                         8.0      朱振生,杨本新,姜仁锋,何纪武,孙建科,吴术,宫惠明
# 2031                        10.0                 张晓旭,傅国强,乔新一,管振全
# ...
