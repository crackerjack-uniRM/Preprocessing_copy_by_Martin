# %% [markdown]
# # Dependent Modules

# %%
# import required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Variable definitions
# | Variable abbv. | Explanation |
# | ---- | ---- |
# | PTCT | Public Trade Company Types |
# | MDC | Missing Data Count |
# | ML | Management layer |
# |

# %%
# read puclic trade company types data
PTCT = pd.read_excel('../data/raw/上市公司行业类型.xlsx')

PTCT.columns = [col.replace('\n', '') for col in PTCT.columns]
PTCT.head(5)
# Out:
#         证券代码  证券简称 所属行业名称[行业标准] 申万行业[行业级别] 一级行业       上市日期  \
# 0  000001.SZ  平安银行                           银行 1991-04-03
# 1  000002.SZ   万科A                          房地产 1991-01-29
# 2  000004.SZ  国华网安                          计算机 1991-01-14
# 3  000005.SZ  ST星源                         公用事业 1990-12-10
# 4  000006.SZ  深振业A                          房地产 1992-04-27
#
#    支付给职工以及为职工支付的现金[报告期] 2010年报[报表类型] 合并报表[单位] 元  \
# 0                                  3.747634e+09
# 1                                  1.848828e+09
# 2                                  1.353200e+07
# 3                                  3.088473e+07
# 4                                  5.417853e+07
#
#    支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元  \
# 0                                  5.287265e+09
# 1                                  2.480848e+09
# 2                                  1.497066e+07
# 3                                  3.898805e+07
# 4                                  6.921623e+07
#
# ...

# %%
# could number of missing values in each column
MDC = pd.DataFrame(PTCT.isnull().sum(), columns=['Missing Data Count'])
MDC.tail(5)
# Out:
#                  Missing Data Count
# 年末所得税率[年度] 2014                1069
# 年末所得税率[年度] 2015                 875
# 年末所得税率[年度] 2016                 650
# 年末所得税率[年度] 2017                 347
# 年末所得税率[年度] 2018                  15

# %%
PTCT.columns
# Out:
# Index(['证券代码', '证券简称', '所属行业名称[行业标准] 申万行业[行业级别] 一级行业', '上市日期',
#        '支付给职工以及为职工支付的现金[报告期] 2010年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2011年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2012年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2013年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2014年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2015年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2016年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2017年报[报表类型] 合并报表[单位] 元',
#        '支付给职工以及为职工支付的现金[报告期] 2018年报[报表类型] 合并报表[单位] 元',
#        '非独立董事人数[交易日期] 2010-12-31', '非独立董事人数[交易日期] 2011-12-31',
#        '非独立董事人数[交易日期] 2012-12-31', '非独立董事人数[交易日期] 2013-12-31',
#        '非独立董事人数[交易日期] 2014-12-31', '非独立董事人数[交易日期] 2015-12-31',
#        '非独立董事人数[交易日期] 2016-12-31', '非独立董事人数[交易日期] 2017-12-31',
#        '非独立董事人数[交易日期] 2018-12-31', '公司监事(历任)[交易日期] 2010-12-31',
#        '公司监事(历任)[交易日期] 2011-12-31', '公司监事(历任)[交易日期] 2012-12-31',
# ...
